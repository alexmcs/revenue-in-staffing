# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Plotly" data-toc-modified-id="Plotly-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Plotly</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#Sankey" data-toc-modified-id="Sankey-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sankey</a></span></li><li><span><a href="#Grouping-by-accounts" data-toc-modified-id="Grouping-by-accounts-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Grouping by accounts</a></span></li></ul></div>

# %%
import psycopg2 as pg
import pandas as pd
import numpy as np
import pandas.io.sql as psql
import datetime
from dateutil.relativedelta import relativedelta
import time
import sys
sys.path.append('../src')
from datahub import PostgreSQLBase, ToDatahubWriter
import seaborn as sns
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(asctime)s - %(name)s : %(levelname)s : %(message)s')

consoleHandler = logging.StreamHandler()
consoleHandler.setFormatter(formatter)
logger.addHandler(consoleHandler)

import auxiliary as aux
reload (aux)

postgres = PostgreSQLBase()
df_proc = aux.DataFrameProcessor()
loc_ids = aux.City_Country()

# %% [markdown]
# # Plotly

# %%
# !pip install plotly --upgrade
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/ff/75/3982bac5076d0ce6d23103c03840fcaec90c533409f9d82c19f54512a38a/plotly-3.10.0-py2.py3-none-any.whl (41.5MB)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from plotly) (2019.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.0.6 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from plotly) (4.4.0)
# Requirement already satisfied, skipping upgrade: six in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from plotly) (1.12.0)
# Collecting retrying>=1.3.3 (from plotly)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Requirement already satisfied, skipping upgrade: requests in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from plotly) (2.21.0)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from plotly) (4.4.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from requests->plotly) (1.24.2)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from requests->plotly) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from requests->plotly) (2019.3.9)
# Requirement already satisfied, skipping upgrade: ipython_genutils in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.1 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied, skipping upgrade: jupyter_core in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Requirement already satisfied, skipping upgrade: enum34 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from traitlets>=4.1->nbformat>=4.2->plotly) (1.1.6)
# Requirement already satisfied, skipping upgrade: functools32 in c:\users\alexey_yakunin\appdata\local\continuum\anaconda2\envs\wpm-ds-revenue-in-staffing\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly) (3.2.3.post2)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Alexey_Yakunin\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-3.10.0 retrying-1.3.3
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.

# %%
import plotly.plotly as py
import plotly
plotly.__version__
# Out:
# u'3.10.0'

# %%
import plotly.plotly as py

data = dict(
    type='sankey',
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(
        color = "black",
        width = 0.5
      ),
      label = ["A1", "A2", "B1", "B2", "C1", "C2", "C3"],
      color = ["blue", "blue", "blue", "blue", "blue", "blue", "red"]
    ),
    link = dict(
      source = [0,1,0,2,3,3,2],
      target = [2,3,3,4,4,5,6],
      value = [8,4,2,6,4,2,2]
  ))

layout =  dict(
    title = "Basic Sankey Diagram",
    font = dict(
      size = 10
    )
)

fig = dict(data=[data], layout=layout)
py.iplot(fig, validate=False)
# Out:
# 2019-06-21 17:05:58,467 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-21 17:05:59,905 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/33.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Data

# %%
snaps = ['2019-02-01', '2019-02-07', '2019-02-14',
         '2019-03-01', '2019-03-07', '2019-03-14',
         '2019-04-01', '2019-04-07', '2019-04-14',
         '2019-05-01', '2019-05-07', '2019-05-14',
         '2019-06-01', '2019-06-07', '2019-06-14', '2019-06-21']

# %%
sub_snaps = [s for s in snaps if int(s[6]) >= int(max_date[6])]

# %%
[s for s in sub_snaps if int(s[6]) == int(max_date[6])+1
] + [s for s in sub_snaps if (s[8:] == '01')&(int(s[6]) > int(max_date[6])+1)] + snaps[-1:]
# Out:
# ['2019-04-01',
#  '2019-04-07',
#  '2019-04-14',
#  '2019-05-01',
#  '2019-06-01',
#  '2019-06-21']

# %%
# %%time
d = datetime.datetime.strptime('2019-01-01', '%Y-%m-%d')

for i in range(5):
    
    min_date = datetime.datetime.strftime(d + relativedelta(months=i), '%Y-%m-%d')
    max_date = datetime.datetime.strftime(d + relativedelta(months=i+1), '%Y-%m-%d')
    
    sub_snaps = [s for s in snaps if int(s[6]) >= int(max_date[6])]
    days = [s for s in sub_snaps if int(s[6]) == int(max_date[6])
        ] + [s for s in sub_snaps if (s[8:] == '01')&(int(s[6]) >= int(max_date[6])+1)] + snaps[-1:]
    
    params = (min_date, max_date, list(days))
    
    logger.info('{0}, {1}, {2}'.format(*params))

    df = postgres.get_data('time_reporting_changes.sql', param=params, param_type='tuple')
    
    df.to_pickle('../data/time_reporting_changes{}.pkl'.format(min_date))
# Out:
# 2019-06-21 20:48:35,744 - root : INFO : 2019-01-01, 2019-02-01, ['2019-02-01', '2019-02-07', '2019-02-14', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-06-21']
# 2019-06-21 21:37:07,286 - root : INFO : 2019-02-01, 2019-03-01, ['2019-03-01', '2019-03-07', '2019-03-14', '2019-04-01', '2019-05-01', '2019-06-01', '2019-06-21']
# 2019-06-21 22:02:01,917 - root : INFO : 2019-03-01, 2019-04-01, ['2019-04-01', '2019-04-07', '2019-04-14', '2019-05-01', '2019-06-01', '2019-06-21']
# 2019-06-21 22:21:47,660 - root : INFO : 2019-04-01, 2019-05-01, ['2019-05-01', '2019-05-07', '2019-05-14', '2019-06-01', '2019-06-21']
# 2019-06-21 22:35:36,151 - root : INFO : 2019-05-01, 2019-06-01, ['2019-06-01', '2019-06-07', '2019-06-14', '2019-06-21', '2019-06-21']
# Wall time: 2h 16s

# %%
df.shape

# %%
df = pd.read_pickle('../data/time_reporting_changes.pkl')

# %% [markdown]
# # Sankey

# %%
def time_report_moving(month='Jan', corr='yes'):
    
    def regular(x):

        d1 = x['from'][:10]
        d2 = x['to'][:10]
        b = x['from'][11:]

        if b == 'billable':
            s = df[
                (df.date.astype(str) == d1) &
                (df.billable == True) &
                (df.id.isin(
                    df[
                        (df.date.astype(str) == d2) &
                        (df.billable == True)
                    ].id 
                ))
            ].duration.sum()

        else:
            s = df[
                (df.date.astype(str) == d1) &
                (df.billable == False) &
                (df.id.isin(
                    df[
                        (df.date.astype(str) == d2) &
                        (df.billable == False)
                    ].id 
                ))
            ].duration.sum()

        return s

    def correct(x):

        b = x['from'][11:]
        v = x['val']
        d_min = min(df.date.unique().astype(str))
        d_max = max(df.date.unique().astype(str))

        if b == 'billable':

            corr = df[
                (df.date.astype(str) == d_min) &
                (df.billable == True) &
                (df.id.isin(
                    df[
                        (df.date.astype(str) == d_max) &
                        (df.billable == True)
                    ].id 
                ))
            ].duration.sum()

        else:

            corr = df[
                (df.date.astype(str) == d_min) &
                (df.billable == False) &
                (df.id.isin(
                    df[
                        (df.date.astype(str) == d_max) &
                        (df.billable == False)
                    ].id 
                ))
            ].duration.sum()

        return (v-corr)

    def to_cancel(x):

        d1 = x['from'][:10]
        d2 = min([d for d in df.date.unique().astype(str) if d > d1])
        b = x['from'][11:]

        if b == 'billable':
            s = df[
                (df.date.astype(str) == d1) &
                (df.billable == True) &
                (~df.id.isin(
                    df[
                        (df.date.astype(str) == d2) &
                        (df.billable == True)
                    ].id 
                ))
            ].duration.sum()

        else:
            s = df[
                (df.date.astype(str) == d1) &
                (df.billable == False) &
                (~df.id.isin(
                    df[
                        (df.date.astype(str) == d2) &
                        (df.billable == False)
                    ].id 
                ))
            ].duration.sum()

        return s

    def from_new(x):

        d2 = x['to'][:10]
        d1 = max([d for d in df.date.unique().astype(str) if d < d2])
        b = x['to'][11:]

        if b == 'billable':
            s = df[
                (df.date.astype(str) == d2) &
                (df.billable == True) &
                (~df.id.isin(
                    df[
                        (df.date.astype(str) == d1) &
                        (df.billable == True)
                    ].id 
                ))
            ].duration.sum()

        else:
            s = df[
                (df.date.astype(str) == d2) &
                (df.billable == False) &
                (~df.id.isin(
                    df[
                        (df.date.astype(str) == d1) &
                        (df.billable == False)
                    ].id 
                ))
            ].duration.sum()

        return s
    
    
    months = {
        'Jan' : '2019-01-01',
        'Feb' : '2019-02-01',
        'Mar' : '2019-03-01',
        'Apr' : '2019-04-01',
        'May' : '2019-05-01'
    }
    
    df = pd.read_pickle('../data/time_reporting_changes{}.pkl'.format(months[month]))
    
    lables = ['New hours', 'Cancelled hours']
    for d in df.date.unique().astype(str):
        for b in ['billable', 'NONbillable']:
            lables.append(d + '_' + b)
            
    colors = ['blue', 'red'] + ['blue' if l[-11:] == 'NONbillable' else 'green' for l in lables][2:]
    
    moves = []
    for d1 in list(df.date.unique().astype(str))[:-1]:
        d2 = min([d for d in df.date.unique().astype(str) if d > d1])
        for b in ['billable', 'NONbillable']:
            moves.append([d1 + '_' + b, d2 + '_' + b])
    moves = pd.DataFrame(moves, columns=['from', 'to'])
    
    moves_from = moves.copy()
    moves_from['from'] = 'New hours'
    moves_to = moves.copy()
    moves_to['to'] = 'Cancelled hours'

    moves['val'] = moves.apply(regular, axis=1)
    
    if corr == 'yes':
        moves['val'] = moves.apply(correct, axis=1)
        
    moves_from['val'] = moves_from.apply(from_new, axis=1)
    moves_to['val'] = moves_to.apply(to_cancel, axis=1)

    moves = pd.concat([moves, moves_from, moves_to])

    moves['from_id'] = moves['from'].map(lambda x: [i for i,l in enumerate(lables) if l == x][0]).astype(int)
    moves['to_id'] = moves['to'].map(lambda x: [i for i,l in enumerate(lables) if l == x][0]).astype(int)

    data = dict(
        type='sankey',
        node = dict(
          pad = 15,
          thickness = 20,
          line = dict(
            color = "black",
            width = 0.5
          ),
          label = lables,
          color = colors
        ),
        link = dict(
          source = list(moves['from_id']),
          target = list(moves['to_id']),
          value = list(moves['val'])
      ))

    layout =  dict(
        title = "{} hours".format(month),
        font = dict(
          size = 10
        )
    )

    fig = dict(data=[data], layout=layout)
    
    plotly.offline.init_notebook_mode(connected=True)
    
    display(py.iplot(fig, validate=False))
    
    
    moves.to_pickle('../data/time_reporting_final_{}.pkl'.format(months[month]))

# %%
# %%time
time_report_moving(month='Jan', corr='yes')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 08:41:39,740 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 08:41:41,635 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/101.embed" height="525px" width="100%"></iframe>
# Wall time: 11min 1s

# %%
# %%time
time_report_moving(month='Feb', corr='yes')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 08:49:47,904 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 08:49:49,479 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/103.embed" height="525px" width="100%"></iframe>
# Wall time: 8min 8s

# %%
# %%time
time_report_moving(month='Mar', corr='yes')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 08:55:52,862 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 08:55:54,266 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/105.embed" height="525px" width="100%"></iframe>
# Wall time: 6min 3s

# %%
# %%time
time_report_moving(month='Apr', corr='yes')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 09:00:34,497 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 09:00:35,936 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/107.embed" height="525px" width="100%"></iframe>
# Wall time: 4min 40s

# %%
# %%time
time_report_moving(month='May', corr='yes')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 09:04:04,301 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 09:04:06,144 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/109.embed" height="525px" width="100%"></iframe>
# Wall time: 3min 29s

# %%
# %%time
time_report_moving(month='Jan', corr='no')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 09:12:15,822 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 09:12:17,403 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/111.embed" height="525px" width="100%"></iframe>
# Wall time: 8min 16s

# %%
# %%time
time_report_moving(month='Feb', corr='no')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 09:18:34,186 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 09:18:36,595 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/113.embed" height="525px" width="100%"></iframe>
# Wall time: 6min 18s

# %%
# %%time
time_report_moving(month='Mar', corr='no')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 09:23:27,654 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 09:23:29,098 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/115.embed" height="525px" width="100%"></iframe>
# Wall time: 4min 50s

# %%
# %%time
time_report_moving(month='Apr', corr='no')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 09:27:13,364 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 09:27:14,996 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/117.embed" height="525px" width="100%"></iframe>
# Wall time: 3min 44s

# %%
# %%time
time_report_moving(month='May', corr='no')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2019-06-23 09:30:03,644 - urllib3.connectionpool : DEBUG : Starting new HTTPS connection (1): plot.ly:443
# 2019-06-23 09:30:05,635 - urllib3.connectionpool : DEBUG : https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~alex20dc/119.embed" height="525px" width="100%"></iframe>
# Wall time: 2min 49s

# %% [markdown]
# # Grouping by accounts

# %%
# %%time
df = pd.read_pickle('../data/time_reporting_changes2019-01-01.pkl')
# Out:
# Wall time: 2min 55s

# %%
len(df.bind_position_id.unique())
# Out:
# 29167

# %%
# %%time
proj = set(df.project_uid_projection.unique()) - set(['npa', 'vac'])

proj = postgres.get_data('bind_projects_by_positions.sql', param=list(
    proj), param_type='list')
# Out:
# Wall time: 25.9 s

# %%
proj
# Out:
#               external_id  container account
# 0     4060741400008851014    SAP-SRS     SAP
# 1     4060741400361423235   REFI-TLD    REFI
# 2     4060741400048518062    MTR-MAX     MTR
# 3     4060741400036241377  HARP-DEV2    HARP
# 4     4060741400354876397    WKF-SPD     WKF
# 5     4060741400344520722  KNGC-CONS    KNGC
# 6     4060741400009313798   EPM-CHRT     EPM
# 7     4060741400022946620  EASY-INDI    EASY
# 8     4060741400035436623  CRDF-SITE    CRDF
# 9     4060741400039644513    ASW-HUF     ASW
# 10    4060741400364886395   BRD-PLHD     BRD
# 11    4060741400048287339    IHG-LOY     IHG
# 12    4060741400356877555  MCKC-JAVA    MCKC
# 13    4060741400048772787  TKDG-FIAT    TKDG
# 14    4060741400302465886   CHEV-GTC    CHEV
# 15    4060741400359095242  TKMI-3PSC    TKMI
# 16    4060741400318126513  DMLR-VBE1    DMLR
# 17    4060741400367506126    BDA-OPS     BDA
# 18    4060741400327952433   MANO-ERP    MANO
# 19    4060741400343168466   SCIM-XDV    SCIM
# 20    4060741400046709568   WKF-PROD     WKF
# 21    4060741400337847430   SLON-SIR    SLON
# 22    4060741400305888844   UBS-07L1     UBS
# 23    4060741400009010865   EPM-CMST     EPM
# 24    4060741400331880103   EPM-RDBY     EPM
# 25    4060741400036482061  CLGX-TREN    CLGX
# 26    4060741400330793663  LOOK-SITE    LOOK
# 27    4060741400048517148  MCKH-CXT1    MCKH
# 28    4060741400358333250  PNSK-LRS2    PNSK
# 29    4060741400008846910   LILY-ADM    LILY
# ...                   ...        ...     ...
# 2155  4060741400356554435    THK-PLT     THK
# 2156  4060741400339983237   DBSS-SG1    DBSS
# 2157  4060741400371027376  SCHR-DPLT    SCHR
# 2158  4060741400008080169  CTCO-DSUP    CTCO
# 2159  4060741400372334253   ERCN-GCP    ERCN
# 2160  4060741400362284622  WFBH-COVE    WFBH
# 2161  4060741400359237042  REFI-ENVA    REFI
# 2162  4060741400036362692  CTCO-FGLS    CTCO
# 2163  4060741400356506277  CORU-DATA    CORU
# 2164  4060741400374798140   EPM-SFOP     EPM
# 2165  4060741400354031590    AMW-LAT     AMW
# 2166  4060741400347458329  CTCO-CIAM    CTCO
# 2167  4060741400042876753  MADV-MCOP    MADV
# 2168  4060741400007472332  GOOG-BZPS     GO3
# 2169  4060741400039299108    EPM-REF     EPM
# 2170  4060741400009445398  GOOG-GSAD     GO1
# 2171  4060741400035259117  BMSQ-KNCT    BMSQ
# 2172  4060741400312621256    TKM-FXO     TKM
# 2173  4060741400041603610   MRC-BGDT     MRC
# 2174  4060741400037128421  EHRM-CORE    EHRM
# 2175  4000741400011858446   PIPE-001     PLS
# 2176  4060741400047068201   DOW-PERF     DOW
# 2177  4060741400370695251   VER-NETS     VER
# 2178  4060741400354857917   LIBG-OBO    LIBG
# 2179  4060741400036247789  MCKH-DV11    MCKH
# 2180  4060741400336220465   TBC-SUPP     TBC
# 2181  4060741400343814775  VRTX-YSUP    VRTX
# 2182  4060741400006304619    IDL-MPG     IDL
# 2183  4060741400311235961   KRON-INT    KRON
# 2184  4060741400354479454  CTCO-REPB    CTCO
#
# [2185 rows x 3 columns]

# %%
proj.external_id = proj.external_id.astype(str)

# %%
df.shape
# Out:
# (7139381, 16)

# %%
df = pd.merge(
    df, proj.set_index('external_id'), how='left',
    left_on = 'project_uid_projection', right_index = True
)

# %%
df.shape
# Out:
# (7139381, 18)

# %%
df['bucket'] = np.where(df.project_uid_projection == 'npa', 'NPA', 
                        np.where(df.project_uid_projection == 'vac', 'VAC', df.account)
# 7139365  4060741400370041677         94647957
# 7139366  4060741400370041640         94647957
# 7139367  4060741400370041629         94647957
# 7139368  4060741400370041623         94647957
# 7139369  4060741400370041600         94647957
# 7139370  4060741400370041389        123336214
# 7139371  4060741400370040815        125076680
# 7139372  4060741400370040435        102425774
# 7139373  4060741400370040204        108494794
# 7139374  4060741400370040183        108494794
# 7139375  4060741400370040162        108494794
# 7139376  4060741400370040141        108494794
# 7139377  4060741400370030889         71141856
# 7139378  4060741400370030867        109201661
# 7139379  4060741400370030866        108145725
# 7139380  4060741400370030816         13289935
#
#                                                         bt container_name  \
# 0        DateTimeRange(datetime.datetime(2019, 1, 30, 2...      CTCO-ASRC
# 1        DateTimeRange(datetime.datetime(2019, 1, 1, 9,...      CTCO-ORKE
# 2        DateTimeRange(datetime.datetime(2019, 1, 17, 9...      MUFG-MRKT
# 3        DateTimeRange(datetime.datetime(2019, 1, 18, 1...      MUFG-MRKT
# 4        DateTimeRange(datetime.datetime(2019, 1, 29, 1...       NBS-SUPP
# 5        DateTimeRange(datetime.datetime(2019, 1, 11, 1...       NBS-EVIC
# 6        DateTimeRange(datetime.datetime(2018, 11, 6, 1...            NaN
# 7        DateTimeRange(datetime.datetime(2019, 1, 10, 1...       JLP-ECOM
# 8        DateTimeRange(datetime.datetime(2019, 1, 28, 7...            NaN
# 9        DateTimeRange(datetime.datetime(2018, 12, 19, ...            NaN
# 10       DateTimeRange(datetime.datetime(2019, 1, 7, 9,...        RDN-RVP
# 11       DateTimeRange(datetime.datetime(2019, 1, 4, 6,...        RDN-RVP
# 12       DateTimeRange(datetime.datetime(2019, 1, 4, 6,...        RDN-RVP
# 13       DateTimeRange(datetime.datetime(2019, 1, 4, 6,...        RDN-RVP
# 14       DateTimeRange(datetime.datetime(2019, 1, 7, 8,...       IDL-SFRC
# 15       DateTimeRange(datetime.datetime(2019, 1, 4, 1,...            NaN
# 16       DateTimeRange(datetime.datetime(2019, 1, 7, 9,...            NaN
# 17       DateTimeRange(datetime.datetime(2019, 1, 17, 7...        WKH-LRP
# 18       DateTimeRange(datetime.datetime(2019, 1, 17, 7...        WKH-LRP
# 19       DateTimeRange(datetime.datetime(2019, 1, 17, 7...        WKH-LRP
# 20       DateTimeRange(datetime.datetime(2019, 1, 18, 1...       TCO-SAUG
# 21       DateTimeRange(datetime.datetime(2019, 1, 25, 1...            NaN
# 22       DateTimeRange(datetime.datetime(2018, 10, 16, ...            NaN
# 23       DateTimeRange(datetime.datetime(2019, 1, 2, 12...       UBS-04L1
# 24       DateTimeRange(datetime.datetime(2019, 1, 17, 7...        WKH-LRP
# 25       DateTimeRange(datetime.datetime(2019, 1, 9, 7,...      SLBN-FMPI
# 26       DateTimeRange(datetime.datetime(2019, 1, 29, 1...      CTCO-FGLS
# 27       DateTimeRange(datetime.datetime(2019, 1, 13, 5...      CTCO-FGLS
# 28       DateTimeRange(datetime.datetime(2019, 1, 5, 20...      LOWC-UXSC
# 29       DateTimeRange(datetime.datetime(2018, 12, 27, ...       CIGN-IAO
# ...                                                    ...            ...
# 7139351  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      SHRA-DGSZ
# 7139352  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      SHRA-DGSZ
# 7139353  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      SHRA-DGSZ
# 7139354  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      SHRA-DGSZ
# 7139355  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...            NaN
# 7139356  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      SHRA-DGSG
# 7139357  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...       ERT-TST1
# 7139358  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...       ERCN-TVP
# 7139359  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      BURB-CJNY
# 7139360  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...       DELB-HYB
# 7139361  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...        OTW-PLT
# 7139362  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...       INFO-MRI
# 7139363  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      CTCO-ORKE
# 7139364  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...       UBS-09L1
# 7139365  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      TKMI-MFOL
# 7139366  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      TKMI-MFOL
# 7139367  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      TKMI-MFOL
# 7139368  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      TKMI-MFOL
# 7139369  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...      TKMI-MFOL
# 7139370  DateTimeRange(datetime.datetime(2019, 1, 2, 6,...        TRI-EBH
# 7139371  DateTimeRange(datetime.datetime(2019, 1, 2, 5,...       HKLD-CMS
# 7139372  DateTimeRange(datetime.datetime(2019, 1, 2, 5,...      MACD-FCRM
# 7139373  DateTimeRange(datetime.datetime(2019, 1, 2, 4,...       MACD-CAP
# 7139374  DateTimeRange(datetime.datetime(2019, 1, 2, 4,...       MACD-CAP
# 7139375  DateTimeRange(datetime.datetime(2019, 1, 2, 4,...       MACD-CAP
# 7139376  DateTimeRange(datetime.datetime(2019, 1, 2, 4,...       MACD-CAP
# 7139377  DateTimeRange(datetime.datetime(2019, 1, 2, 3,...      UBSJ-AD10
# 7139378  DateTimeRange(datetime.datetime(2019, 1, 2, 3,...      CSAP-PRME
# 7139379  DateTimeRange(datetime.datetime(2019, 1, 2, 3,...      CSAP-EDIT
# 7139380  DateTimeRange(datetime.datetime(2019, 1, 2, 3,...      PGCH-MTS1
#
#                                     customer_name bucket  container account
# 0               Canadian Tire Corporation Limited   CTCO  CTCO-ASRC    CTCO
# 1               Canadian Tire Corporation Limited   CTCO  CTCO-ORKE    CTCO
# 2                                 MUFG Securities   MUFG  MUFG-MRKT    MUFG
# 3                                 MUFG Securities   MUFG  MUFG-MRKT    MUFG
# 4                Novartis Business Services (NBS)    NBS   NBS-SUPP     NBS
# 5                Novartis Business Services (NBS)    NBS   NBS-EVIC     NBS
# 6                                             NaN    VAC        NaN     NaN
# 7                          John Lewis Partnership    JLP   JLP-ECOM     JLP
# 8                                             NaN    NPA        NaN     NaN
# 9                                             NaN    NPA        NaN     NaN
# 10                              Radian Group Inc.    RDN    RDN-RVP     RDN
# 11                              Radian Group Inc.    RDN    RDN-RVP     RDN
# 12                              Radian Group Inc.    RDN    RDN-RVP     RDN
# 13                              Radian Group Inc.    RDN    RDN-RVP     RDN
# 14                                     IHS Markit    IDL   IDL-SFRC     IDL
# 15                                            NaN    NPA        NaN     NaN
# 16                                            NaN    NPA        NaN     NaN
# 17                                 Wolters Kluwer    WKL    WKH-LRP     WKL
# 18                                 Wolters Kluwer    WKL    WKH-LRP     WKL
# 19                                 Wolters Kluwer    WKL    WKH-LRP     WKL
# 20                             Tengizchevroil LLP    TCO   TCO-SAUG     TCO
# 21                                            NaN    NPA        NaN     NaN
# 22                                            NaN    VAC        NaN     NaN
# 23                                         UBS AG    UBS   UBS-04L1     UBS
# 24                                 Wolters Kluwer    WKL    WKH-LRP     WKL
# 25                     Schlumberger North America   SLBN  SLBN-FMPI    SLBN
# 26              Canadian Tire Corporation Limited   CTCO  CTCO-FGLS    CTCO
# 27              Canadian Tire Corporation Limited   CTCO  CTCO-FGLS    CTCO
# 28                        Lowe's Companies Canada   LOWC  LOWC-UXSC    LOWC
# 29                              Cigna Corporation   CIGN   CIGN-IAO    CIGN
# ...                                           ...    ...        ...     ...
# 7139351                            Schroders APAC   SHRA  SHRA-DGSZ    SHRA
# 7139352                            Schroders APAC   SHRA  SHRA-DGSZ    SHRA
# 7139353                            Schroders APAC   SHRA  SHRA-DGSZ    SHRA
# 7139354                            Schroders APAC   SHRA  SHRA-DGSZ    SHRA
# 7139355                                       NaN    NPA        NaN     NaN
# 7139356                            Schroders APAC   SHRA  SHRA-DGSG    SHRA
# 7139357                 eResearch Technology, Inc    ERT   ERT-TST1     ERT
# 7139358                               Ericsson US   ERCN   ERCN-TVP    ERCN
# 7139359                                  Burberry   BURB  BURB-CJNY    BURB
# 7139360                            Delhaize Group   DELB   DELB-HYB    DELB
# 7139361                               OnTimeWorks    OTW    OTW-PLT     OTW
# 7139362                                  Infoblox   INFO   INFO-MRI    INFO
# 7139363         Canadian Tire Corporation Limited   CTCO  CTCO-ORKE    CTCO
# 7139364                                    UBS AG    UBS   UBS-09L1     UBS
# 7139365                   Ticketmaster UK Limited   TKMI  TKMI-MFOL    TKMI
# 7139366                   Ticketmaster UK Limited   TKMI  TKMI-MFOL    TKMI
# 7139367                   Ticketmaster UK Limited   TKMI  TKMI-MFOL    TKMI
# 7139368                   Ticketmaster UK Limited   TKMI  TKMI-MFOL    TKMI
# 7139369                   Ticketmaster UK Limited   TKMI  TKMI-MFOL    TKMI
# 7139370                           Thomson Reuters    TRI    TRI-EBH     TRI
# 7139371                            Hong Kong Land   HKLD   HKLD-CMS    HKLD
# 7139372                                Mastercard   MACD  MACD-FCRM    MACD
# 7139373                                Mastercard   MACD   MACD-CAP    MACD
# 7139374                                Mastercard   MACD   MACD-CAP    MACD
# 7139375                                Mastercard   MACD   MACD-CAP    MACD
# 7139376                                Mastercard   MACD   MACD-CAP    MACD
# 7139377                             UBS AG (APAC)   UBSJ  UBSJ-AD10    UBSJ
# 7139378                        Credit Suisse APAC   CSAP  CSAP-PRME    CSAP
# 7139379                        Credit Suisse APAC   CSAP  CSAP-EDIT    CSAP
# 7139380  Procter & Gamble (China) Trading Company   PGCH  PGCH-MTS1    PGCH
#
# [7139381 rows x 18 columns]

# %%
df['key'] = df.pmc_user_id.astype(str) + df.timesheet_date.astype(str)
